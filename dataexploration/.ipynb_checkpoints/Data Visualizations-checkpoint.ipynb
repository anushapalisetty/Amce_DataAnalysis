# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from data_explr import DataExploration

# %%
## Read the Data
df=pd.read_csv('../data/nbl_eval.csv')
dexp=DataExploration()

# %%
df.source=df.source.astype('category').cat.codes
df.destination=df.destination.astype('category').cat.codes

# %% [markdown]
# ### Visualising Pairs Of Continous Data

# %%
columns=["distanceinmiles","fuelcost","linehaulcost"]
g = sns.pairplot(df[columns],palette="Accent")
g.fig.suptitle("Scatter Plot Of Continous Data",y=1.05)
plt.show()

# %% [markdown]
# ### Visualization of Categorical Feature and Continous Feature

# %%
plt.figure(figsize=[10,6])
sns.boxplot(data=df, x='productid',y='linehaulcost')
plt.ylim([0,6000])
plt.title("BoxPlot Of ProductId and Linehaulcost",fontsize=14)
plt.ylabel("LineHaulCost",fontsize=12)
plt.xlabel("Product",fontsize=12)
plt.show()

# %%
plt.figure(figsize=[10,6])
sns.boxplot(data=df, x='source',y='linehaulcost')
plt.ylim([0,2000])
plt.title("BoxPlot Of Source and Linehaulcost",fontsize=14)
plt.ylabel("LineHaulCost",fontsize=12)
plt.xlabel("Source",fontsize=12)
plt.show()

# %%
sns.catplot(x='destination',y='linehaulcost',data=df,height=5, aspect=10/5.5)
plt.ylim([0,15000])
plt.xlim([0,51])
plt.title("ScatterPlot Of Source and Linehaulcost",fontsize=14)
plt.ylabel("LineHaulCost",fontsize=12)
plt.xlabel("Destination",fontsize=12)
plt.show()

# %%
#sns.catplot(x='truckingcompanyid',y='linehaulcost',data=df.sample(5000),height=6, aspect=2)

# %% [markdown]
# ### Measure Relationship Between Pair Of Categorical Features

# %%
columns=['source','destination','productid','truckingcompanyid']
df_chi=dexp.rel_cat_chisquare(df,columns)
# Out:
#   Categorical_1      Categorical_2  Test_Statistic   P-Value  \
# 0        source        destination     2541.448329  0.000344
# 1        source          productid     1106.655404  0.471838
# 2        source  truckingcompanyid   295228.066482  0.534878
# 3   destination          productid     1199.582653  0.023168
# 4   destination  truckingcompanyid   295346.730802  0.473340
# 5     productid  truckingcompanyid   141183.681907  0.721155
#
#         Statis_Signf         Pval_Signf
# 0          Reject H0          Reject H0
# 1  Fail to Reject H0  Fail to Reject H0
# 2  Fail to Reject H0  Fail to Reject H0
# 3          Reject H0          Reject H0
# 4  Fail to Reject H0  Fail to Reject H0
# 5  Fail to Reject H0  Fail to Reject H0

# %% [markdown]
# ## Collinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
plt.figure(figsize=[10,6])
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['truckingcompanyid', 'productid', 'distanceinmiles', 'fuelcost',
#        'linehaulcost', 'source', 'destination'],
#       dtype='object')

# %%
from patsy import dmatrices

# %%
features =df.columns

# get y and X dataframes based on this regression:
y, X = dmatrices('linehaulcost ~truckingcompanyid+productid+distanceinmiles+fuelcost+source+destination', df, return_type='dataframe')

# %%
#calculate VIF for each explanatory variable
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['variable'] = X.columns

# %%
vif
# Out:
#          VIF           variable
# 0  47.375467          Intercept
# 1   1.000196  truckingcompanyid
# 2   1.000321          productid
# 3   1.006481    distanceinmiles
# 4   1.000265           fuelcost
# 5   1.002854             source
# 6   1.004062        destination
